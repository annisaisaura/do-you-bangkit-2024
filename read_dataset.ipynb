# %% [markdown]
# <a href="https://colab.research.google.com/github/annisaisaura/do-you-bangkit-2024/blob/ml/read_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import package

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Dataset

# %%
# upload token kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-316c805f-4c96-4dfa-bde5-48d6abc4d213" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-316c805f-4c96-4dfa-bde5-48d6abc4d213">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle(1).json
# !pip install kaggle
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `chmod 600 ~/.kaggle/kaggle(1).json'
# ...

# %%
# !kaggle datasets download -d ravindrasinghrana/job-description-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ravindrasinghrana/job-description-dataset
# License(s): CC0-1.0
# ...
#  98% 449M/457M [00:07<00:00, 59.8MB/s]
# 100% 457M/457M [00:07<00:00, 62.1MB/s]

# %%
import zipfile
import os

# Buat direktori untuk ekstraksi jika belum ada
os.makedirs("job_description_dataset", exist_ok=True)

# Ekstraksi file zip
with zipfile.ZipFile("job-description-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("job_description_dataset")

# %%
import pandas as pd

# Baca file CSV dari direktori ekstraksi
df = pd.read_csv("job_description_dataset/job_descriptions.csv")
df.head()
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615940 entries, 0 to 1615939
# Data columns (total 23 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Job Id            1615940 non-null  int64
#  1   Experience        1615940 non-null  object
#  2   Qualifications    1615940 non-null  object
#  3   Salary Range      1615940 non-null  object
#  4   location          1615940 non-null  object
#  5   Country           1615940 non-null  object
#  6   latitude          1615940 non-null  float64
#  7   longitude         1615940 non-null  float64
#  8   Work Type         1615940 non-null  object
#  9   Company Size      1615940 non-null  int64
#  10  Job Posting Date  1615940 non-null  object
#  11  Preference        1615940 non-null  object
#  12  Contact Person    1615940 non-null  object
#  13  Contact           1615940 non-null  object
#  14  Job Title         1615940 non-null  object
# ...
